# %% [markdown]
# ## Imports and Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import json
import os

# Set visual style for the project
plt.style.use("seaborn-v0_8")
sns.set_palette("viridis")

# Ensure results directory exists
RESULTS_DIR = os.path.join('..', 'results')

# %% [markdown]
# ## Load Results

# %%
# Load metric files
metric_files = glob.glob(os.path.join(RESULTS_DIR, '*_metrics.json'))

if not metric_files:
    print(f"Folder found, but no JSON files were found in: {RESULTS_DIR}")
    print("no files found")
else:
    all_metrics = []
    for file_path in metric_files:
        with open(file_path, 'r') as f:
            data = json.load(f)
            # Standardize keys to lowercase
            normalized_data = {k.lower(): v for k, v in data.items()}
            all_metrics.append(normalized_data)

    df_comparison = pd.DataFrame(all_metrics)
    
    # Rename column if needed
    if 'model' in df_comparison.columns:
        df_comparison = df_comparison.rename(columns={'model': 'model_name'})

    # Sort by RMSE
    if 'rmse' in df_comparison.columns:
        df_comparison = df_comparison.sort_values(by='rmse').reset_index(drop=True)
    
    print(f"Successfully loaded {len(all_metrics)} models.")
    display(df_comparison)
# Out:
# Successfully loaded 3 models.
#          model_name         rmse          mae      mape
# 0              LSTM   351.740458   272.657929  0.011531
# 1           XGBoost   404.437149   272.989108  0.011585
# 2  ARIMA (Baseline)  9992.853332  8794.179145  0.422538

# %% [markdown]
# ## Comparative Visualisations

# %%
if not df_comparison.empty:
    fig, ax = plt.subplots(1, 3, figsize=(18, 6)) 

    # RMSE Comparison
    sns.barplot(x='model_name', y='rmse', data=df_comparison, ax=ax[0], palette='viridis')
    ax[0].set_title('RMSE ', fontweight='bold')
    ax[0].set_ylabel('MW')

    # MAE Comparison
    sns.barplot(x='model_name', y='mae', data=df_comparison, ax=ax[1], palette='viridis')
    ax[1].set_title('MAE ', fontweight='bold')
    ax[1].set_ylabel('MW')

    # MAPE Comparison
    df_comparison['mape_pct'] = df_comparison['mape'] * 100
    sns.barplot(x='model_name', y='mape_pct', data=df_comparison, ax=ax[2], palette='viridis')
    ax[2].set_title('MAPE % ', fontweight='bold')
    ax[2].set_ylabel('Percentage Error (%)')

    plt.suptitle('Model Performance Comparison: RMSE vs MAE vs MAPE', fontsize=16, fontweight='bold')
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\ariel\AppData\Local\Temp\ipykernel_19348\1896141045.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='model_name', y='rmse', data=df_comparison, ax=ax[0], palette='viridis')
# C:\Users\ariel\AppData\Local\Temp\ipykernel_19348\1896141045.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='model_name', y='mae', data=df_comparison, ax=ax[1], palette='viridis')
# C:\Users\ariel\AppData\Local\Temp\ipykernel_19348\1896141045.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='model_name', y='mape_pct', data=df_comparison, ax=ax[2], palette='viridis')

# %% [markdown]
# ## Predictions for Time-Seies Plot

# %%
# Load saved arrays for plotting the curves
try:
    actual = np.load(os.path.join(RESULTS_DIR, 'actual_values.npy'))
    arima_preds = np.load(os.path.join(RESULTS_DIR, 'arima_preds.npy')) 
    xgb_preds = np.load(os.path.join(RESULTS_DIR, 'xgb_preds.npy'))
    lstm_preds = np.load(os.path.join(RESULTS_DIR, 'lstm_preds.npy'))
    
    # Plot 144 steps
    window = 144 

    plt.figure(figsize=(16, 6))
    plt.plot(actual[:window], label='Actual Demand', color='black', linewidth=2, alpha=0.7)
    
    plt.plot(arima_preds[:window], label='ARIMA Baseline', color='blue', linestyle='-.', alpha=0.8) 
    plt.plot(xgb_preds[:window], label='XGBoost Forecast', color='green', linestyle='--', alpha=0.9)
    plt.plot(lstm_preds[:window], label='LSTM Forecast', color='#e74c3c', linewidth=1.5)

    plt.title('Time-Series Comparison: 72-Hour Demand Forecast', fontsize=14)
    plt.xlabel('Time Steps (30-min intervals)')
    plt.ylabel('Energy Demand (MW)')
    plt.legend()
    plt.grid(True, alpha=0.2)
    plt.tight_layout()
    plt.show()

except FileNotFoundError as e:
    print(f"Visualisation Error: {e}")
    print("missing prediction files")
